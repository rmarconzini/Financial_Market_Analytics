# %% [markdown]
# # Installazione e import pacchetti

# %%
# %pip install pandas
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
#      -------------------------------------- 242.1/242.1 KB 1.1 MB/s eta 0:00:00
# ...
# You should consider upgrading via the 'c:\Users\marco\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
from openpyxl import Workbook

# %% [markdown]
# # Import dataset DOW-JONES

# %%
# Dow Jones index time series
df_dj = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/DJ_Price.xlsx', header=0, parse_dates=[0], index_col=0)

# %%
df_dj=df_dj.rename(columns={"DJ Industrial Average - Close":"Close_price"})
df_dj.head()
# Out:
#             Close_price
# Date
# 2017-07-10     21408.52
# 2017-07-11     21409.07
# 2017-07-12     21532.14
# 2017-07-13     21553.09
# 2017-07-14     21637.74

# %%
# Costituents of Dow Jones index time series
df_stocks1 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/Stocks_Price.xlsx', header=0, parse_dates=[0], index_col=0)
df_stocks2 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/Stocks_Price1.xlsx', header=0, parse_dates=[0], index_col=0)

# %%
df_stocks1.head()
# Out:
#             DJ Industrial Average - Close  DJ Industrial Average - Volume  \
# Date
# 2017-07-11                       21409.07                        274780.0
# 2017-07-12                       21532.14                        300088.0
# 2017-07-13                       21553.09                        284105.0
# 2017-07-14                       21637.74                        278818.0
# 2017-07-17                       21629.72                        293014.0
#
#             Walgreens Boots Alliance - Close  Microsoft - Close  \
# Date
# 2017-07-11                             77.29              69.99
# 2017-07-12                             77.52              71.15
# 2017-07-13                             78.01              71.77
# 2017-07-14                             78.91              72.78
# 2017-07-17                             79.18              73.35
#
#             UnitedHealth Group - Close  JPMorgan Chase - Close  \
# Date
# ...

# %%
df_stocks2.head()
# Out:
#             Merck & Co - Close  Salesforce - Close  Travelers - Close  \
# Date
# 2017-07-11               59.44               88.35             125.05
# 2017-07-12               59.86               90.40             125.25
# 2017-07-13               59.97               89.57             125.43
# 2017-07-14               60.13               90.00             125.72
# 2017-07-17               59.70               89.29             126.23
#
#             Dow - Close  Visa - Close
# Date
# 2017-07-11          NaN         95.41
# 2017-07-12          NaN         96.18
# 2017-07-13          NaN         95.94
# 2017-07-14          NaN         96.93
# 2017-07-17          NaN         96.83

# %%
df_stocks =pd.concat([df_stocks1, df_stocks2], axis=1)
df_stocks.head()
# Out:
#             DJ Industrial Average - Close  DJ Industrial Average - Volume  \
# Date
# 2017-07-11                       21409.07                        274780.0
# 2017-07-12                       21532.14                        300088.0
# 2017-07-13                       21553.09                        284105.0
# 2017-07-14                       21637.74                        278818.0
# 2017-07-17                       21629.72                        293014.0
#
#             Walgreens Boots Alliance - Close  Microsoft - Close  \
# Date
# 2017-07-11                             77.29              69.99
# 2017-07-12                             77.52              71.15
# 2017-07-13                             78.01              71.77
# 2017-07-14                             78.91              72.78
# 2017-07-17                             79.18              73.35
#
#             UnitedHealth Group - Close  JPMorgan Chase - Close  \
# Date
# ...

# %%
df_stocks=df_stoks.drop(columns=['DJ Industrial Average - Close', 'DJ Industrial Average - Volume'],)
df_stocks.head()
# Out:
#             Walgreens Boots Alliance - Close  Microsoft - Close  \
# Date
# 2017-07-11                             77.29              69.99
# 2017-07-12                             77.52              71.15
# 2017-07-13                             78.01              71.77
# 2017-07-14                             78.91              72.78
# 2017-07-17                             79.18              73.35
#
#             UnitedHealth Group - Close  JPMorgan Chase - Close  \
# Date
# 2017-07-11                      185.95                   92.83
# 2017-07-12                      186.69                   92.51
# 2017-07-13                      185.48                   93.10
# 2017-07-14                      186.90                   92.25
# 2017-07-17                      186.35                   91.39
#
#             Coca-Cola - Close  Honeywell International - Close  \
# Date
# 2017-07-11              44.33                           128.51
# ...

# %%
print(df_stocks.isnull().sum())
# Out:
# Walgreens Boots Alliance - Close      1
# Microsoft - Close                     1
# UnitedHealth Group - Close            0
# JPMorgan Chase - Close                0
# Coca-Cola - Close                     0
# Honeywell International - Close       1
# Johnson & Johnson - Close             0
# Verizon Communications - Close        0
# 3M Co - Close                         0
# Chevron - Close                       0
# IBM - Close                           0
# Amgen - Close                         1
# Procter & Gamble - Close              0
# Goldman Sachs Group - Close           0
# Boeing - Close                        0
# Apple - Close                         1
# NIKE - Close                          0
# American Express - Close              0
# Walt Disney - Close                   0
# Intel - Close                         1
# Walmart - Close                       0
# Cisco Systems - Close                 1
# Caterpillar - Close                   0
# ...

# %% [markdown]
# # NASDAQ 100

# %%
df = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/ListNasdaq_1722.xlsx')

# %%
display(df)
# Out:
#                                    Name   Symbol     2017     2018     2019  \
# 0                    Cintas Corporation  CTAS-US  CTAS-US  CTAS-US  CTAS-US
# 1                      Fastenal Company  FAST-US  FAST-US  FAST-US  FAST-US
# 2      Vodafone Group Plc Sponsored ADR   VOD-US   VOD-US   VOD-US      NaN
# 3          Walgreens Boots Alliance Inc   WBA-US   WBA-US   WBA-US   WBA-US
# 4                          Mattel, Inc.   MAT-US   MAT-US      NaN      NaN
# ..                                  ...      ...      ...      ...      ...
# 149                       Zscaler, Inc.    ZS-US      NaN      NaN      NaN
# 150  CrowdStrike Holdings, Inc. Class A  CRWD-US      NaN      NaN      NaN
# 151                 Datadog Inc Class A  DDOG-US      NaN      NaN      NaN
# 152                   Lucid Group, Inc.  LCID-US      NaN      NaN      NaN
# 153                Airbnb, Inc. Class A  ABNB-US      NaN      NaN      NaN
#
#         2020     2021     2022
# ...

# %%
df_nonan = df.dropna(axis=0)
display(df_nonan)
# Out:
#                                    Name   Symbol     2017     2018     2019  \
# 0                    Cintas Corporation  CTAS-US  CTAS-US  CTAS-US  CTAS-US
# 1                      Fastenal Company  FAST-US  FAST-US  FAST-US  FAST-US
# 3          Walgreens Boots Alliance Inc   WBA-US   WBA-US   WBA-US   WBA-US
# 5                        Autodesk, Inc.  ADSK-US  ADSK-US  ADSK-US  ADSK-US
# 6                  Analog Devices, Inc.   ADI-US   ADI-US   ADI-US   ADI-US
# ..                                  ...      ...      ...      ...      ...
# 93                    T-Mobile US, Inc.  TMUS-US  TMUS-US  TMUS-US  TMUS-US
# 98   JD.com, Inc. Sponsored ADR Class A    JD-US    JD-US    JD-US    JD-US
# 99          Meta Platforms Inc. Class A  META-US  META-US  META-US  META-US
# 103               PayPal Holdings, Inc.  PYPL-US  PYPL-US  PYPL-US  PYPL-US
# 104                 Kraft Heinz Company   KHC-US   KHC-US   KHC-US   KHC-US
#
#         2020     2021     2022
# ...

# %%
df_nonan.to_excel('ListComplete.xlsx')

# %%
df_25 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/NASDAQ_25.xlsx', header=0, parse_dates=[0], index_col=0)
df_50 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/NASDAQ_50.xlsx', header=0, parse_dates=[0], index_col=0)
df_75 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/NASDAQ_75.xlsx', header=0, parse_dates=[0], index_col=0)
df_100 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/NASDAQ_100.xlsx', header=0, parse_dates=[0], index_col=0)
df_102 = pd.read_excel('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECTS/FinancialMarketAnalytics2022/Financial_Market_Analytics/Dataset/NASDAQ_102.xlsx', header=0, parse_dates=[0], index_col=0)

# %%
df_25
# Out:
#             Analog Devices - Close  Walgreens Boots Alliance - Close  \
# Date
# 2017-07-31                   79.01                             80.67
# 2017-08-01                   78.95                             81.13
# 2017-08-02                   78.82                             81.03
# 2017-08-03                   77.94                             81.05
# 2017-08-04                   77.78                             81.06
# ...                            ...                               ...
# 2022-07-01                  142.91                             38.56
# 2022-07-05                  143.07                             38.51
# 2022-07-06                  144.70                             37.78
# 2022-07-07                  148.57                             38.21
# 2022-07-08                  149.94                             37.55
#
#             Skyworks Solutions - Close  Honeywell International - Close  \
# Date
# ...

# %%
df_concat =pd.concat([df_25, df_50, df_75, df_100, df_102], axis=1)

# %%
df_concat.to_excel('df_concat.xlsx')

# %%
df_concat.head()
# Out:
#             Analog Devices - Close  Walgreens Boots Alliance - Close  \
# Date
# 2017-07-31                   79.01                             80.67
# 2017-08-01                   78.95                             81.13
# 2017-08-02                   78.82                             81.03
# 2017-08-03                   77.94                             81.05
# 2017-08-04                   77.78                             81.06
#
#             Skyworks Solutions - Close  Honeywell International - Close  \
# Date
# 2017-07-31                      104.87                           130.33
# 2017-08-01                      104.28                           131.18
# 2017-08-02                      104.43                           132.82
# 2017-08-03                      101.79                           133.62
# 2017-08-04                      102.55                           134.08
#
#             Cintas - Close  ANSYS - Close  Qualcomm - Close  \
# Date
# ...

# %%
df_concat_nonan=df_concat.dropna(axis=1)
display(df_concat_nonan)
# Out:
#             Analog Devices - Close  Walgreens Boots Alliance - Close  \
# Date
# 2017-07-31                   79.01                             80.67
# 2017-08-01                   78.95                             81.13
# 2017-08-02                   78.82                             81.03
# 2017-08-03                   77.94                             81.05
# 2017-08-04                   77.78                             81.06
# ...                            ...                               ...
# 2022-07-01                  142.91                             38.56
# 2022-07-05                  143.07                             38.51
# 2022-07-06                  144.70                             37.78
# 2022-07-07                  148.57                             38.21
# 2022-07-08                  149.94                             37.55
#
#             Skyworks Solutions - Close  Honeywell International - Close  \
# Date
# ...

# %%
ciao = df_concat.isnull().sum()

# %%
df_concat.info
# Out:
# <bound method DataFrame.info of             Analog Devices - Close  Walgreens Boots Alliance - Close  \
# Date
# 2017-07-31                   79.01                             80.67
# 2017-08-01                   78.95                             81.13
# 2017-08-02                   78.82                             81.03
# 2017-08-03                   77.94                             81.05
# 2017-08-04                   77.78                             81.06
# ...                            ...                               ...
# 2022-07-01                  142.91                             38.56
# 2022-07-05                  143.07                             38.51
# 2022-07-06                  144.70                             37.78
# 2022-07-07                  148.57                             38.21
# 2022-07-08                  149.94                             37.55
#
#             Skyworks Solutions - Close  Honeywell International - Close  \
# Date
# ...
